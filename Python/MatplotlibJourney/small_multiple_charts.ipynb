# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt 
from pypalettes import load_cmap

# %%
url = "https://raw.githubusercontent.com/JosephBARBIERDARNAL/data-matplotlib-journey/refs/heads/main/economic/economic.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#            country        date  consumer confidence  interest rates  \
# 0        australia  2020-01-01                 93.4            0.75
# 1        australia  2020-02-01                 95.5            0.75
# 2        australia  2020-03-01                 91.9            0.50
# 3        australia  2020-04-01                 75.6            0.25
# 4        australia  2020-05-01                 88.1            0.25
# ..             ...         ...                  ...             ...
# 427  united states  2023-08-01                 71.2            5.50
# 428  united states  2023-09-01                 67.7            5.50
# 429  united states  2023-10-01                 63.8            5.50
# 430  united states  2023-11-01                 61.3            5.50
# 431  united states  2023-12-01                 69.7            5.50
#
#      unemployment rate
# 0                  5.2
# 1                  5.1
# 2                  5.2
# 3                  6.3
# 4                  7.0
# ...

# %%
df['country'].unique()
# Out:
# array(['australia', 'canada', 'china', 'europe', 'japan', 'new zealand',
#        'switzerland', 'united kingdom', 'united states'], dtype=object)

# %%
df['date'].unique()
# Out:
# array(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#        '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#        '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#        '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#        '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#        '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#        '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#        '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#        '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#        '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01'],
#       dtype=object)

# %%
# data has 9 countries. each country has 48 rows of values represent each month from Jan 2020 to Dec 2023

# %%
# setting color theme 
colors = load_cmap('Antique').colors
background_color = "#f2f2f2"

# %%
countries = df.country.unique()
countries
# Out:
# array(['australia', 'canada', 'china', 'europe', 'japan', 'new zealand',
#        'switzerland', 'united kingdom', 'united states'], dtype=object)

# %%
countries = df['country'].unique()
countries
# Out:
# array(['australia', 'canada', 'china', 'europe', 'japan', 'new zealand',
#        'switzerland', 'united kingdom', 'united states'], dtype=object)

# %%
date  = df['date'].unique()
date
# Out:
# array(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#        '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#        '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#        '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#        '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#        '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#        '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#        '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#        '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#        '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01'],
#       dtype=object)

# %%
df['date']
# Out:
# 0      2020-01-01
# 1      2020-02-01
# 2      2020-03-01
# 3      2020-04-01
# 4      2020-05-01
#           ...
# 427    2023-08-01
# 428    2023-09-01
# 429    2023-10-01
# 430    2023-11-01
# 431    2023-12-01
# Name: date, Length: 432, dtype: object

# %%
df_usa = df[df['country'] == 'united states']

# %%
df_usa
# Out:
#            country        date  consumer confidence  interest rates  \
# 384  united states  2020-01-01                 99.8            1.75
# 385  united states  2020-02-01                101.0            1.75
# 386  united states  2020-03-01                 89.1            1.25
# 387  united states  2020-04-01                 71.8            0.25
# 388  united states  2020-05-01                 72.3            0.25
# 389  united states  2020-06-01                 78.1            0.25
# 390  united states  2020-07-01                 72.5            0.25
# 391  united states  2020-08-01                 74.1            0.25
# 392  united states  2020-09-01                 80.4            0.25
# 393  united states  2020-10-01                 81.8            0.25
# 394  united states  2020-11-01                 76.9            0.25
# 395  united states  2020-12-01                 80.7            0.25
# 396  united states  2021-01-01                 79.0            0.25
# ...

# %%
fig, ax = plt.subplots()
ax.plot(
    df_usa['date'],
    df_usa['consumer confidence'],
)
ax.set_xticks(['2020-01-01', '2022-01-01', '2024-01-01'],
               labels = [2020,2022,2024])
ax.set_ylim([-60,130])
ax.set_yticks([-50,0,50,100])
ax.set_facecolor(background_color)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(
    df['date'],
    df[df['country'] == 'united states'],
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(
#       3     df['date'],
#       4     df[df['country'] == 'united states'],
#       5 )
#       7 plt.show()
#
# File c:\Users\dqthi\Documents\PandasWorkout\myenv\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# ...

# %%
# setting layout  
fig, axs = plt.subplots(
    nrows = 3,
    ncols = 3,
    layout = 'tight'
)

countries = df['country'].unique()

for focus_country, ax in zip(countries, axs.flat):
    for i,country in enumerate(countries):
        subset = df[df.country == country]
        if focus_country == country:
            zorder = 10
            color = colors[i]
            lw = 2 
            ax.text(x = '2024-01-01', y = 110,
                    s=focus_country.title(),
                    size = 10, ha = 'right',
                    color = color,
                    fontweight = 'bold')
        else:
            color = 'darkgrey'
            lw = 0.3
            zorder = -10
        ax.plot(subset["date"], subset["consumer confidence"], color = color, lw = lw, zorder = zorder)
    
    ax.grid(axis = "y", lw = 0.3)
    ax.spines[["top", "right", "bottom"]].set_visible(False)
    ax.tick_params(length = 0, labelsize= 6)
    ax.set_xticks(['2020-01-01', '2022-01-01', '2024-01-01'],
                labels = [2020,2022,2024])
    ax.set_ylim([-60,130])
    ax.set_yticks([-50,0,50,100])
    ax.set_facecolor(background_color)
fig.set_facecolor(background_color)
plt.show()
