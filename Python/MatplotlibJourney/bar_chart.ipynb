# %%
import matplotlib.pyplot as plt

# %%
bars = plt.bar([0,1,2], height=[3,5,2])
# bar = bars[0]   # get the first bar (a Rectangle)
# print(dir(bar))

# %%
bar = bars[0]   # get the first bar (a Rectangle)

# %%
bar

# %%
print(bar)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=3, angle=0)

# %%
print(dir(bar))
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_agg_filter', '_alias_map', '_alpha', '_animated', '_antialiased', '_aspect_ratio_correction', '_axes', '_callbacks', '_capstyle', '_clipon', '_clippath', '_cm_set', '_convert_units', '_convert_xy_units', '_dash_pattern', '_different_canvas', '_draw_paths_with_artist_properties', '_edge_default', '_edgecolor', '_facecolor', '_fill', '_fully_clipped_to_axes', '_gid', '_hatch', '_hatch_color', '_hatch_linewidth', '_height', '_in_layout', '_internal_update', '_joinstyle', '_label', '_linestyle', '_linewidth', '_mouseover', '_original_edgecolor', '_original_facecolor', '_parent_figure', '_path_effect
# ...

# %%
print(bars[1].properties())
# Out:
# {'agg_filter': None, 'alpha': None, 'angle': 0.0, 'animated': False, 'antialiased': True, 'bbox': Bbox([[0.6, 0.0], [1.4, 5.0]]), 'capstyle': 'butt', 'center': array([1. , 2.5]), 'children': [], 'clip_box': <matplotlib.transforms.TransformedBbox object at 0x000001BA45AE85D0>, 'clip_on': True, 'clip_path': None, 'corners': array([[0.6, 0. ],
#        [1.4, 0. ],
#        [1.4, 5. ],
# ...

# %%
from matplotlib.patches import Rectangle
help(Rectangle)
# Out:
# Help on class Rectangle in module matplotlib.patches:
#
# class Rectangle(Patch)
#  |  Rectangle(xy, width, height, *, angle=0.0, rotation_point='xy', **kwargs)
#  |
#  |  A rectangle defined via an anchor point *xy* and its *width* and *height*.
#  |
#  |  The rectangle extends from ``xy[0]`` to ``xy[0] + width`` in x-direction
#  |  and from ``xy[1]`` to ``xy[1] + height`` in y-direction. ::
#  |
#  |    :                +------------------+
#  |    :                |                  |
#  |    :              height               |
#  |    :                |                  |
#  |    :               (xy)---- width -----+
#  |
#  |  One may picture *xy* as the bottom left corner, but which corner *xy* is
#  |  actually depends on the direction of the axis and the sign of *width*
#  |  and *height*; e.g. *xy* would be the bottom right corner if the x-axis
#  |  was inverted or if *width* was negative.
#  |
#  |  Method resolution order:
#  |      Rectangle
#  |      Patch
# ...
