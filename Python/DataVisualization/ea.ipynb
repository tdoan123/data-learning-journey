# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------------------------ --- 3.7/4.0 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 18.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\dqthi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
url = "https://d18rn0p25nwr6d.cloudfront.net/CIK-0000712515/4d4c1f06-0d61-45d7-8991-a001e911dfe0.html"
tables = pd.read_html(url)

# %%
print(f"Found {len(tables)} tables")
# Out:
# Found 1096 tables

# %%
tables[0]
# Out:
#                        Cover - USD ($)  $ in Millions  \
#                        Cover - USD ($)  $ in Millions
# 0                                    Cover [Abstract]
# 1                                       Document Type
# 2                              Document Annual Report
# 3                            Document Period End Date
# 4                        Current Fiscal Year End Date
# 5                          Document Transition Report
# 6                                  Entity File Number
# 7                              Entity Registrant Name
# 8         Entity Incorporation, State or Country Code
# 9                    Entity Tax Identification Number
# 10                   Entity Address, Address Line One
# 11                       Entity Address, City or Town
# 12                  Entity Address, State or Province
# 13                    Entity Address, Postal Zip Code
# 14                                     City Area Code
# ...

# %%
tables
# Out:
# [                       Cover - USD ($)  $ in Millions  \
#                         Cover - USD ($)  $ in Millions
#  0                                    Cover [Abstract]
#  1                                       Document Type
#  2                              Document Annual Report
#  3                            Document Period End Date
#  4                        Current Fiscal Year End Date
#  5                          Document Transition Report
#  6                                  Entity File Number
#  7                              Entity Registrant Name
#  8         Entity Incorporation, State or Country Code
#  9                    Entity Tax Identification Number
#  10                   Entity Address, Address Line One
#  11                       Entity Address, City or Town
#  12                  Entity Address, State or Province
#  13                    Entity Address, Postal Zip Code
#  14                                     City Area Code
# ...

# %%
path = r'C:\Users\dqthi\Downloads\2025q2\num.txt'

df = pd.read_csv(path, sep=None, engine="python")

# %%
ea = df[df["adsh"].str.startswith("0000712515")]

# %%
ea
# Out:
#                          adsh                                           tag  \
# 138619   0000712515-25-000022            AdditionalPaidInCapitalCommonStock
# 138620   0000712515-25-000022      AvailableForSaleSecuritiesDebtSecurities
# 138621   0000712515-25-000022      AvailableForSaleSecuritiesDebtSecurities
# 138622   0000712515-25-000022      AvailableForSaleSecuritiesDebtSecurities
# 138623   0000712515-25-000022      AvailableForSaleSecuritiesDebtSecurities
# ...                       ...                                           ...
# 3004733  0000712515-25-000022                            StockholdersEquity
# 3004734  0000712515-25-000022                            StockholdersEquity
# 3004735  0000712515-25-000022  StockRepurchasedAndRetiredDuringPeriodShares
# 3004736  0000712515-25-000022   StockRepurchasedAndRetiredDuringPeriodValue
# 3004737  0000712515-25-000022   StockRepurchasedAndRetiredDuringPeriodValue
#
#               version     ddate  qtrs     uom  \
# ...

# %%
pd.set_option("display.max_rows", None)

# %%
ea
# Out:
#                          adsh  \
# 138619   0000712515-25-000022
# 138620   0000712515-25-000022
# 138621   0000712515-25-000022
# 138622   0000712515-25-000022
# 138623   0000712515-25-000022
# 138624   0000712515-25-000022
# 138625   0000712515-25-000022
# 138626   0000712515-25-000022
# 138627   0000712515-25-000022
# 138628   0000712515-25-000022
# 138629   0000712515-25-000022
# 138630   0000712515-25-000022
# 138631   0000712515-25-000022
# 138632   0000712515-25-000022
# 138633   0000712515-25-000022
# 138634   0000712515-25-000022
# 138635   0000712515-25-000022
# 138636   0000712515-25-000022
# 138637   0000712515-25-000022
# 138638   0000712515-25-000022
# 138639   0000712515-25-000022
# 138640   0000712515-25-000022
# 138641   0000712515-25-000022
# 138642   0000712515-25-000022
# 138643   0000712515-25-000022
# 138644   0000712515-25-000022
# 138645   0000712515-25-000022
# 138646   0000712515-25-000022
# 138647   0000712515-25-000022
# 138648   0000712515-25-000022
# ...

# %%
ea['ddate'].unique()
# Out:
# array([20240331, 20250331, 20230331, 20220331])

# %%
ea.to_excel("my_data.xlsx", index=False)
