# %%
import pandas as pd
from pandas import DataFrame

# %%
filepath = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\oecd_locations.csv"

oced_df = pd.read_csv(filepath, header=None, names = ['abbrev', 'country'], index_col= 'abbrev')

# %%
oced_df
# Out:
#                country
# abbrev
# AUS          Australia
# AUT            Austria
# BEL            Belgium
# CAN             Canada
# DNK            Denmark
# FIN            Finland
# FRA             France
# DEU            Germany
# HUN            Hungary
# ITA              Italy
# JPN              Japan
# KOR              Korea
# GBR     United Kingdom
# USA      United States
# BRA             Brazil
# ISR             Israel

# %%
filepath2 = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\oecd_tourism.csv"

oced_tourism_df = pd.read_csv(filepath2, 
                              usecols= ['LOCATION', 'TIME', 'Value', 'SUBJECT'],
                              index_col = 'LOCATION')

# %%
oced_tourism_df
# Out:
#           SUBJECT  TIME      Value
# LOCATION
# AUS       INT_REC  2008  31159.800
# AUS       INT_REC  2009  29980.700
# AUS       INT_REC  2010  35165.500
# AUS       INT_REC  2011  38710.100
# AUS       INT_REC  2012  38003.700
# ...           ...   ...        ...
# SRB       INT-EXP  2015   1253.644
# SRB       INT-EXP  2016   1351.098
# SRB       INT-EXP  2017   1549.183
# SRB       INT-EXP  2018   1837.317
# SRB       INT-EXP  2019   1999.313
#
# [1234 rows x 3 columns]

# %%
oced_tourism_df2 = oced_tourism_df.loc[oced_tourism_df['SUBJECT'] == 'INT-EXP']

# %%
oced_tourism_df2 = oced_tourism_df2.drop('SUBJECT', axis = 1)

# %%
oced_tourism_df2
# Out:
#           TIME      Value
# LOCATION
# AUS       2008  27620.000
# AUS       2009  25629.600
# AUS       2010  31916.500
# AUS       2011  39381.500
# AUS       2012  41632.800
# ...        ...        ...
# SRB       2015   1253.644
# SRB       2016   1351.098
# SRB       2017   1549.183
# SRB       2018   1837.317
# SRB       2019   1999.313
#
# [617 rows x 2 columns]

# %%
# my approach above is slower as I break the steps down to 3 line of code: 
# line 1: calling the file for the dataframe 
# line 2: search for keyword in column "SUBJECT"
# line 3: remove the column after completing the search

# %%
# this code is from the text book. this combines all the steps required to filter column that content word "INT-EXP" then remove the column
oecd_tourism_df3 = (
    pd
    .read_csv(filepath2,
              usecols=['LOCATION', 'TIME',
                       'Value', 'SUBJECT'],
              index_col='LOCATION')
    .loc[lambda df_: df_['SUBJECT'] == 'INT-EXP']
    .drop('SUBJECT', axis='columns')
)

# %%
oecd_tourism_df3
# Out:
#           TIME      Value
# LOCATION
# AUS       2008  27620.000
# AUS       2009  25629.600
# AUS       2010  31916.500
# AUS       2011  39381.500
# AUS       2012  41632.800
# ...        ...        ...
# SRB       2015   1253.644
# SRB       2016   1351.098
# SRB       2017   1549.183
# SRB       2018   1837.317
# SRB       2019   1999.313
#
# [617 rows x 2 columns]

# %%
oced_tourism_df2
# Out:
#           TIME      Value
# LOCATION
# AUS       2008  27620.000
# AUS       2009  25629.600
# AUS       2010  31916.500
# AUS       2011  39381.500
# AUS       2012  41632.800
# ...        ...        ...
# SRB       2015   1253.644
# SRB       2016   1351.098
# SRB       2017   1549.183
# SRB       2018   1837.317
# SRB       2019   1999.313
#
# [617 rows x 2 columns]

# %%
oced_tourism_df2.head()
# Out:
#           TIME    Value
# LOCATION
# AUS       2008  27620.0
# AUS       2009  25629.6
# AUS       2010  31916.5
# AUS       2011  39381.5
# AUS       2012  41632.8

# %%
oced_tourism_df2.groupby('LOCATION')['Value'].mean()
# Out:
# LOCATION
# AUS     36727.966667
# AUT     11934.563636
# BEL     20859.883455
# BGR      1562.641750
# BRA     21564.351833
# CAN     40984.633333
# CHE     15775.966667
# CHL      2409.591667
# CHN    163217.404417
# COL      4381.633333
# CRI       867.075000
# CZE      4898.278545
# DEU     96615.075545
# DNK     11326.169636
# EGY      3202.420750
# ESP     21601.955273
# EST      1122.501909
# FIN      5877.080909
# FRA     51394.272273
# GBR     75262.227273
# GRC      3486.849818
# HRV      1115.628083
# HUN      2918.390182
# IDN     10058.441667
# IND     17050.493083
# IRL      7030.703818
# ISL      1072.819636
# ISR      6726.524833
# ITA     34148.908455
# JPN     32197.925000
# KAZ      2606.684083
# KOR     25573.509091
# LTU      1189.933333
# LUX      3355.510636
# LVA       919.545455
# MAR      2299.033750
# MEX     11469.027273
# MLT       387.801667
# NLD     22278.809091
# NOR     15667.881818
# NZL      4698.900000
# PER      2236.278583
# PHL      8961.027250
# ...

# %%
test1_df = oced_df.join(oced_tourism_df2)

# %%
test1_df
# Out:
#           country  TIME    Value
# abbrev
# AUS     Australia  2008  27620.0
# AUS     Australia  2009  25629.6
# AUS     Australia  2010  31916.5
# AUS     Australia  2011  39381.5
# AUS     Australia  2012  41632.8
# ...           ...   ...      ...
# ISR        Israel  2015   7507.0
# ISR        Israel  2016   8210.3
# ISR        Israel  2017   8986.0
# ISR        Israel  2018   9974.7
# ISR        Israel  2019  10389.5
#
# [182 rows x 3 columns]

# %%
test1 = test1_df.groupby('country')['Value'].mean()

# %%
test2_df = oced_tourism_df2.join(oced_df)

# %%
test2_df
# Out:
#           TIME      Value    country
# LOCATION
# AUS       2008  27620.000  Australia
# AUS       2009  25629.600  Australia
# AUS       2010  31916.500  Australia
# AUS       2011  39381.500  Australia
# AUS       2012  41632.800  Australia
# ...        ...        ...        ...
# SRB       2015   1253.644        NaN
# SRB       2016   1351.098        NaN
# SRB       2017   1549.183        NaN
# SRB       2018   1837.317        NaN
# SRB       2019   1999.313        NaN
#
# [617 rows x 3 columns]

# %%
# Question: the different between test1_df (oced_df.join(oced_tourism_df2)) and test2_df (oced_tourism_df2.join(oced_df)) are the len of the row, which i thought should be the same, but the lens are actually diferent 
# test1_df has 182 rows 
# test2_df has 617 rows

# %%
tourism_spending = (
    oced_df.join(oced_tourism_df2).groupby('country')['Value'].mean()
    )

# %%
test1 == tourism_spending
# Out:
# country
# Australia         True
# Austria           True
# Belgium           True
# Brazil            True
# Canada            True
# Denmark           True
# Finland           True
# France            True
# Germany           True
# Hungary           True
# Israel            True
# Italy             True
# Japan             True
# Korea             True
# United Kingdom    True
# United States     True
# Name: Value, dtype: bool

# %%
tourism_spending.head()
# Out:
# country
# Australia    36727.966667
# Austria      11934.563636
# Belgium      20859.883455
# Brazil       21564.351833
# Canada       40984.633333
# Name: Value, dtype: float64

# %%
filepath3 = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\winemag-150k-reviews.csv"

wine_df = pd.read_csv(filepath3, usecols=['country', 'points'])

# %%
wine_df.head()
# Out:
#   country  points
# 0      US      96
# 1   Spain      96
# 2      US      96
# 3      US      96
# 4  France      95

# %%
country_points = (
    wine_df
    .groupby('country')['points'].mean()
)

# %%
country_points
# Out:
# country
# Albania                   88.000000
# Argentina                 85.996093
# Australia                 87.892475
# Austria                   89.276742
# Bosnia and Herzegovina    84.750000
# Brazil                    83.240000
# Bulgaria                  85.467532
# Canada                    88.239796
# Chile                     86.296768
# China                     82.000000
# Croatia                   86.280899
# Cyprus                    85.870968
# Czech Republic            85.833333
# Egypt                     83.666667
# England                   92.888889
# France                    88.925870
# Georgia                   85.511628
# Germany                   88.626427
# Greece                    86.117647
# Hungary                   87.329004
# India                     87.625000
# Israel                    87.176190
# Italy                     88.413664
# Japan                     85.000000
# Lebanon                   85.702703
# Lithuania                 84.250000
# ...

# %%
country_points.sort_values(ascending=False).head()
# Out:
# country
# England    92.888889
# Austria    89.276742
# France     88.925870
# Germany    88.626427
# Italy      88.413664
# Name: points, dtype: float64

# %%
country_points.to_frame().join(tourism_spending)
# Out:
#                            points         Value
# country
# Albania                 88.000000           NaN
# Argentina               85.996093           NaN
# Australia               87.892475  36727.966667
# Austria                 89.276742  11934.563636
# Bosnia and Herzegovina  84.750000           NaN
# Brazil                  83.240000  21564.351833
# Bulgaria                85.467532           NaN
# Canada                  88.239796  40984.633333
# Chile                   86.296768           NaN
# China                   82.000000           NaN
# Croatia                 86.280899           NaN
# Cyprus                  85.870968           NaN
# Czech Republic          85.833333           NaN
# Egypt                   83.666667           NaN
# England                 92.888889           NaN
# France                  88.925870  51394.272273
# Georgia                 85.511628           NaN
# Germany                 88.626427  96615.075545
# ...

# %%
oced_df.join(oced_df, lsuffix='_l', rsuffix='_r')
# Out:
#              country_l       country_r
# abbrev
# AUS          Australia       Australia
# AUT            Austria         Austria
# BEL            Belgium         Belgium
# CAN             Canada          Canada
# DNK            Denmark         Denmark
# FIN            Finland         Finland
# FRA             France          France
# DEU            Germany         Germany
# HUN            Hungary         Hungary
# ITA              Italy           Italy
# JPN              Japan           Japan
# KOR              Korea           Korea
# GBR     United Kingdom  United Kingdom
# USA      United States   United States
# BRA             Brazil          Brazil
# ISR             Israel          Israel

# %%
country_points.to_frame().join(tourism_spending,
                               how='outer')
# Out:
#                            points          Value
# country
# Albania                 88.000000            NaN
# Argentina               85.996093            NaN
# Australia               87.892475   36727.966667
# Austria                 89.276742   11934.563636
# Belgium                       NaN   20859.883455
# Bosnia and Herzegovina  84.750000            NaN
# Brazil                  83.240000   21564.351833
# Bulgaria                85.467532            NaN
# Canada                  88.239796   40984.633333
# Chile                   86.296768            NaN
# China                   82.000000            NaN
# Croatia                 86.280899            NaN
# Cyprus                  85.870968            NaN
# Czech Republic          85.833333            NaN
# Denmark                       NaN   11326.169636
# Egypt                   83.666667            NaN
# England                 92.888889            NaN
# Finland                       NaN    5877.080909
# ...

# %%
country_points.to_frame().join(
    tourism_spending, how='outer').corr()
# Out:
#           points     Value
# points  1.000000  0.288231
# Value   0.288231  1.000000

# %%
filepath = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\oecd_locations.csv"

oecd_df = pd.read_csv(filepath, header=None, names = ['abbrev', 'country'])

# %%
oecd_df
# Out:
#    abbrev         country
# 0     AUS       Australia
# 1     AUT         Austria
# 2     BEL         Belgium
# 3     CAN          Canada
# 4     DNK         Denmark
# 5     FIN         Finland
# 6     FRA          France
# 7     DEU         Germany
# 8     HUN         Hungary
# 9     ITA           Italy
# 10    JPN           Japan
# 11    KOR           Korea
# 12    GBR  United Kingdom
# 13    USA   United States
# 14    BRA          Brazil
# 15    ISR          Israel

# %%
filepath2 = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\oecd_tourism.csv"

oecd_tourism_df = (
    pd
    .read_csv(filepath2, usecols= ['LOCATION', 'TIME', 'Value', 'SUBJECT'])
    .loc[lambda df_: df_['SUBJECT'] == 'INT-EXP']
    .drop('SUBJECT', axis = 'columns')
)

# %%
oecd_tourism_df
# Out:
#      LOCATION  TIME      Value
# 12        AUS  2008  27620.000
# 13        AUS  2009  25629.600
# 14        AUS  2010  31916.500
# 15        AUS  2011  39381.500
# 16        AUS  2012  41632.800
# ...       ...   ...        ...
# 1229      SRB  2015   1253.644
# 1230      SRB  2016   1351.098
# 1231      SRB  2017   1549.183
# 1232      SRB  2018   1837.317
# 1233      SRB  2019   1999.313
#
# [617 rows x 3 columns]

# %%
import numpy as np

# %%
oecd_tourism_df['Value'] = oecd_tourism_df['Value'].astype(np.int64)

# %%
oecd_tourism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 617 entries, 12 to 1233
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  617 non-null    object
#  1   TIME      617 non-null    int64
#  2   Value     617 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 19.3+ KB

# %%
oecd_tourism_df.rename(columns = {'LOCATION':'abbrev'}, inplace= True)

# %%
oecd_tourism_df
# Out:
#      abbrev  TIME  Value
# 12      AUS  2008  27620
# 13      AUS  2009  25629
# 14      AUS  2010  31916
# 15      AUS  2011  39381
# 16      AUS  2012  41632
# ...     ...   ...    ...
# 1229    SRB  2015   1253
# 1230    SRB  2016   1351
# 1231    SRB  2017   1549
# 1232    SRB  2018   1837
# 1233    SRB  2019   1999
#
# [617 rows x 3 columns]

# %%
filepath3 = r"C:\Users\dqthi\Downloads\pandas-workout-data\data\winemag-150k-reviews.csv"

wine_df2 = pd.read_csv(filepath3, usecols=['country', 'points'])

# %%
wine_df2
# Out:
#        country  points
# 0           US      96
# 1        Spain      96
# 2           US      96
# 3           US      96
# 4       France      95
# ...        ...     ...
# 150925   Italy      91
# 150926  France      91
# 150927   Italy      91
# 150928  France      90
# 150929   Italy      90
#
# [150930 rows x 2 columns]

# %%
oecd_tourism_df.merge(oecd_df, how = 'inner', on = 'abbrev')
# Out:
#     abbrev  TIME  Value    country
# 0      AUS  2008  27620  Australia
# 1      AUS  2009  25629  Australia
# 2      AUS  2010  31916  Australia
# 3      AUS  2011  39381  Australia
# 4      AUS  2012  41632  Australia
# ..     ...   ...    ...        ...
# 177    ISR  2015   7507     Israel
# 178    ISR  2016   8210     Israel
# 179    ISR  2017   8986     Israel
# 180    ISR  2018   9974     Israel
# 181    ISR  2019  10389     Israel
#
# [182 rows x 4 columns]

# %%
tourism_spending_df = oecd_df.merge(oecd_tourism_df, how = 'inner', on = 'abbrev')

# %%
tourism_spending2 = (
    tourism_spending_df.groupby('country')['Value'].mean()
)

# %%
tourism_spending_df2 = tourism_spending2.to_frame()

# %%
wine_point_df = wine_df2.groupby('country')['points'].mean().to_frame()

# %%
wine_point_df.shape
# Out:
# (48, 1)

# %%
wine_point_df.merge(tourism_spending_df2, how ='inner', on = 'country')
# Out:
#               points         Value
# country
# Australia  87.892475  36727.500000
# Austria    89.276742  11934.000000
# Brazil     83.240000  21563.833333
# Canada     88.239796  40984.250000
# France     88.925870  51393.909091
# Germany    88.626427  96614.636364
# Hungary    87.329004   2918.090909
# Israel     87.176190   6726.083333
# Italy      88.413664  34148.272727
# Japan      85.000000  32197.500000

# %%
tourism_spending_df2.merge(wine_point_df, how ='outer', on = 'country')
# Out:
#                                 Value     points
# country
# Albania                           NaN  88.000000
# Argentina                         NaN  85.996093
# Australia                36727.500000  87.892475
# Austria                  11934.000000  89.276742
# Belgium                  20859.272727        NaN
# Bosnia and Herzegovina            NaN  84.750000
# Brazil                   21563.833333  83.240000
# Bulgaria                          NaN  85.467532
# Canada                   40984.250000  88.239796
# Chile                             NaN  86.296768
# China                             NaN  82.000000
# Croatia                           NaN  86.280899
# Cyprus                            NaN  85.870968
# Czech Republic                    NaN  85.833333
# Denmark                  11325.636364        NaN
# Egypt                             NaN  83.666667
# England                           NaN  92.888889
# Finland                   5876.545455        NaN
# ...
