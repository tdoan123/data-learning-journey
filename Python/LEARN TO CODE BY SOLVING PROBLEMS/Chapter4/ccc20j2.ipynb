# %%
p = int(input())
n = int(input())
r = int(input())

day = 0
daily_infect = 0  
total_infect = 0  

while total_infect < p: 
    daily_infect = n * r
    print(f'test daily infect {daily_infect}')
    total_infect += daily_infect 
    print(f'test total infect {total_infect}') 
    day += 1 
    print(f'test day {day}')

print (day)
print (total_infect)
# Out:
# test daily infect 5
# test total infect 5
# test day 1
# test daily infect 5
# test total infect 10
# test day 2
# test daily infect 5
# test total infect 15
# test day 3
# test daily infect 5
# test total infect 20
# test day 4
# test daily infect 5
# test total infect 25
# test day 5
# test daily infect 5
# test total infect 30
# test day 6
# test daily infect 5
# test total infect 35
# test day 7
# test daily infect 5
# test total infect 40
# test day 8
# test daily infect 5
# test total infect 45
# test day 9
# test daily infect 5
# test total infect 50
# test day 10
# test daily infect 5
# test total infect 55
# test day 11
# test daily infect 5
# test total infect 60
# test day 12
# test daily infect 5
# test total infect 65
# test day 13
# test daily infect 5
# test total infect 70
# test day 14
# test daily infect 5
# test total infect 75
# test day 15
# test daily infect 5
# test total infect 80
# test day 16
# test daily infect 5
# test total infect 85
# test day 17
# ...

# %%
p = int(input())
n = int(input())
r = int(input())

day = 0
daily_infect = 0  
total_infect = 0  

while total_infect < p: 
    if day == 0: 
        daily_infect = n * r    
        print(f'test daily infect {daily_infect}')
        total_infect += daily_infect 
        print(f'test total infect {total_infect}') 
        day += 1 
        print(f'test day {day}')
    
    else: 
        daily_infect = daily_infect * r    
        print(f'test daily infect2 {daily_infect}')
        total_infect += daily_infect 
        print(f'test total infect2 {total_infect}') 
        day += 1 
        print(f'test day2 {day}')

print (day)
print (total_infect)
# Out:
# test daily infect 5
# test total infect 5
# test day 1
# test daily infect2 25
# test total infect2 30
# test day2 2
# test daily infect2 125
# test total infect2 155
# test day2 3
# test daily infect2 625
# test total infect2 780
# test day2 4
# 4
# 780

# %%
p = int(input())
n = int(input())
r = int(input())

day = 0
daily_infect = n  
total_infect = n  

while total_infect < p: 
    if day == 0: 
        daily_infect = n * r    
    else: 
        daily_infect = daily_infect * r    
    total_infect += daily_infect 
    day += 1 

print(day)
# Out:
# 4

# %%
target_infected = int(input())
number_infected = int(input())
person_infects = int(input())

day = 0 
prev_day = number_infected  

while day <= 10: 
    prev_day = prev_day * person_infects 
    print(f'prev_day is {prev_day}')
    day += 1     
    
# while number_infected <= target_infected:
#     number_infected = number_infected + prev_day * person_infects  
#     print(f'number_infected is {number_infected}')
#     prev_day = prev_day * person_infects 
#     print(f'prev_day is {prev_day}')
#     day += 1  

print(day)
# Out:
# prev_day is 5
# prev_day is 25
# prev_day is 125
# prev_day is 625
# prev_day is 3125
# prev_day is 15625
# prev_day is 78125
# prev_day is 390625
# prev_day is 1953125
# prev_day is 9765625
# prev_day is 48828125
# 11

# %%
target_infected = int(input())
number_infected = int(input())
person_infects = int(input())

day = 0 
prev_day = number_infected  

while number_infected <= target_infected:
    number_infected = number_infected + prev_day * person_infects  
    print(f'number_infected is {number_infected}')
    prev_day = prev_day * person_infects 
    print(f'prev_day is {prev_day}')
    day += 1  

print(day)
# Out:
# number_infected is 6
# prev_day is 5
# number_infected is 31
# prev_day is 25
# number_infected is 156
# prev_day is 125
# number_infected is 781
# prev_day is 625
# 4
